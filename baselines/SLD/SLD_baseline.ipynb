# %%
# from google.colab import drive
# drive.mount("/content/drive/")

# %%
# Choose the SLD folder
# %cd sld

# %%
# # --- Download and Install Miniconda ---
# !wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -bfp /usr/local
# !conda init bash
# !conda config --set auto_update_conda false
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r

# %%
# !conda create -n sld python=3.10 --yes

# %%
# @title First install depencendies
# !conda run -n sld pip install git+https://github.com/ml-research/safe-latent-diffusion &> /dev/null
# !!conda run -n sld pip install ftfy &> /dev/null

# %%
# !conda run -n sld pip install -r requirements.txt

# %%
# !conda run -n sld pip install pandas huggingface_hub==0.25.0

# %%
# %%time
# !conda run -n sld python generate_by_sld.py \
  --base_model "CompVis/stable-diffusion-v1-4" \
  --prompts_path prompts/sld_generate_van-gogh.csv \
  --save_path "outputs/van-gogh/" \
  --safety_concept "van gogh" \
  --num_inference_steps 50 \
  --num_samples 1

# %%
# %%time
# !conda run -n sld python generate_by_sld.py \
  --base_model "CompVis/stable-diffusion-v1-4" \
  --prompts_path prompts/sld_generate_kelly-mckernan.csv \
  --save_path "outputs/kelly-mckernan/" \
  --safety_concept "kelly mckernan" \
  --num_inference_steps 50 \
  --num_samples 1
